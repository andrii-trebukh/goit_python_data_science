# %%
# Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv
# Прочитайте отриману таблицю, використовуючи метод head
import pandas as pd


survey = pd.read_csv("2017_jun_final.csv")
survey.head()
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# ...

# %%
# Визначте розмір таблиці за допомогою методу shape
survey.shape
# Out:
# (8704, 25)

# %%
# Визначте типи всіх стовпців за допомогою dataframe.dtypes
survey.dtypes
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# ...

# %%
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)
round((survey.isnull().sum()/survey.shape[0])*100, 2) # percentage of missing values in each column
# Out:
# N                                    0.00
# Посада                               0.00
# Мова програмування                  44.23
# Спеціалізація                       82.94
# Загальний досвід роботи              0.00
# Досвід роботи на поточному місці     0.00
# Зарплата на місяць                   0.00
# Зміна зарплати за 12 місяців         0.00
# Місто                                0.00
# Розмір компанії                      0.00
# Тип компанії                         0.00
# Стать                                0.00
# Вік                                  0.00
# Освіта                               0.00
# Університет                          4.11
# Ще студент                           0.00
# Рівень англійської                   0.00
# Предметна область                    2.56
# Дата заповнення                      0.00
# User.Agent                           0.00
# exp                                  0.00
# current_job_exp                      0.00
# ...

# %%
# Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"
rm_headers = survey.columns[survey.isnull().any()]
rm_headers = rm_headers.drop("Мова програмування")
survey.drop(rm_headers, axis=1, inplace=True)
survey
# Out:
#          N                    Посада Мова програмування  \
# 0        1        Junior QA engineer                NaN
# 1        2        Junior QA engineer                NaN
# 2        3         Software Engineer            C#/.NET
# 3        4         Software Engineer         JavaScript
# 4        5  Senior Software Engineer         JavaScript
# ...    ...                       ...                ...
# 8699  8700               QA engineer                NaN
# 8700  8701                 Marketing                NaN
# 8701  8702  Junior Software Engineer         Ruby/Rails
# 8702  8703                 Team lead                NaN
# 8703  8704  Senior Software Engineer               Java
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                        0.5                              0.5
# 1            менше 3 місяців                  менше 3 місяців
# 2                          4                                1
# ...

# %%
# Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"
round((survey.isnull().sum()/survey.shape[0])*100, 2) # percentage of missing values in each column
# Out:
# N                                    0.00
# Посада                               0.00
# Мова програмування                  44.23
# Загальний досвід роботи              0.00
# Досвід роботи на поточному місці     0.00
# Зарплата на місяць                   0.00
# Зміна зарплати за 12 місяців         0.00
# Місто                                0.00
# Розмір компанії                      0.00
# Тип компанії                         0.00
# Стать                                0.00
# Вік                                  0.00
# Освіта                               0.00
# Ще студент                           0.00
# Рівень англійської                   0.00
# Дата заповнення                      0.00
# User.Agent                           0.00
# exp                                  0.00
# current_job_exp                      0.00
# salary                               0.00
# dtype: float64

# %%
# Видаліть усі рядки у вихідній таблиці за допомогою методу dropna
survey.dropna(inplace=True)
survey
# Out:
#          N                    Посада Мова програмування  \
# 2        3         Software Engineer            C#/.NET
# 3        4         Software Engineer         JavaScript
# 4        5  Senior Software Engineer         JavaScript
# 6        7  Junior Software Engineer            C#/.NET
# 7        8  Senior Software Engineer                C++
# ...    ...                       ...                ...
# 8692  8693         Software Engineer               Java
# 8694  8695  Junior Software Engineer            C#/.NET
# 8695  8696         Software Engineer             Python
# 8701  8702  Junior Software Engineer         Ruby/Rails
# 8703  8704  Senior Software Engineer               Java
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 2                          4                                1
# 3                          5                                4
# 4          10 і більше років                              0.5
# ...

# %%
# Визначте новий розмір таблиці за допомогою методу shape
survey.shape
# Out:
# (4854, 20)

# %%
# Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python
python_data = survey[survey["Мова програмування"] == "Python"]
python_data
# Out:
#          N                    Посада Мова програмування  \
# 12      13         Software Engineer             Python
# 68      69         Software Engineer             Python
# 87      88  Junior Software Engineer             Python
# 114    115  Junior Software Engineer             Python
# 143    144  Junior Software Engineer             Python
# ...    ...                       ...                ...
# 8546  8547         Software Engineer             Python
# 8625  8626         Software Engineer             Python
# 8635  8636  Senior Software Engineer             Python
# 8673  8674  Junior Software Engineer             Python
# 8695  8696         Software Engineer             Python
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 12                         1                  менше 3 місяців
# 68                       1.5                              0.5
# 87                       0.5                              0.5
# ...

# %%
# Визначте розмір таблиці python_data за допомогою методу shape
python_data.shape
# Out:
# (207, 20)

# %%
# Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"
python_data_by_position = python_data.groupby("Посада")

# %%
# Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"
# python_data_by_position = pd.DataFrame(python_data.groupby("Посада"))
# python_data_by_position
python_data_salary = python_data_by_position.agg({"Зарплата на місяць": ['min', 'max']})
python_data_salary
# Out:
#                          Зарплата на місяць
#                                         min   max
# Посада
# Junior Software Engineer                100  1250
# Senior Software Engineer               1300  9200
# Software Engineer                       500  5400
# System Architect                       3000  5000
# Technical Lead                         1425  6200

# %%
# Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"
def fill_avg_salary(data):
    return data.mean()


python_data_salary["Зарплата на місяць", "avg"] = python_data_salary.apply(fill_avg_salary, axis=1)
python_data_salary
# Out:
#                          Зарплата на місяць
#                                         min   max     avg
# Посада
# Junior Software Engineer                100  1250   675.0
# Senior Software Engineer               1300  9200  5250.0
# Software Engineer                       500  5400  2950.0
# System Architect                       3000  5000  4000.0
# Technical Lead                         1425  6200  3812.5

# %%
# Створіть описову статистику за допомогою методу describe для нового стовпчика.
python_data_salary["Зарплата на місяць", "avg"].describe()
# Out:
# count       5.000000
# mean     3337.500000
# std      1700.091909
# min       675.000000
# 25%      2950.000000
# 50%      3812.500000
# 75%      4000.000000
# max      5250.000000
# Name: (Зарплата на місяць, avg), dtype: float64

# %%
# Збережіть отриману таблицю в CSV файл
python_data_salary.to_csv("python_data_salary.csv")

# %%
# додайте від 3 до 5 графіків функцій різного типу на ваш вибір
# 1
import seaborn as sns


ax = sns.boxplot(x="Місто", y="Зарплата на місяць", data=survey)
ax.tick_params(axis='x', rotation=90)

# %%
# 2

order=["Junior Software Engineer", "Software Engineer", "Senior Software Engineer", "Technical Lead", "System Architect"]
ax = sns.violinplot(x="Посада", y="Зарплата на місяць", data=python_data, order=order)
ax.tick_params(axis='x', rotation=90)

# %%
# 3

sorter = {
    'менше 3 місяців': 0,
    '0.25': 1,
    '0.5': 2,
    '1': 3,
    '1.5': 4,
    '2': 5,
    '3': 6,
    '4': 7,
    '5': 8,
    '6': 9,
    '7': 10,
    '8': 11,
    '9': 12,
    '10 і більше років': 13
}
python_data = python_data.sort_values("Загальний досвід роботи", key=lambda x: x.map(sorter))

ax = sns.stripplot(x="Посада", y="Загальний досвід роботи", hue="Посада", data=python_data, order=order)
ax.tick_params(axis='x', rotation=90)
ax.invert_yaxis()
