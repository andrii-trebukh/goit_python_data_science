# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Line Graphs

# %%
x = np.array([1, 2, 3, 4, 5, 6])
y = np.power(x, 3)

plt.plot(x, y)
plt.show()

# %%
x = np.linspace(0, 10, 1000) 
y = np.sin(x) 
plt.plot(x, y)
plt.show()

# %%
x = np.linspace(0, 10, 1000) 
y = np.sin(x) 

plt.figure(figsize=(10, 6))

plt.plot(x, y, 'b^') #r-

plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.show()

# %%
plt.figure(figsize=(10, 5))
x = np.linspace(0, 10, 40) 
y = np.sin(x)
y1 = x * 0
plt.plot(x, y1)
plt.plot(x, y,'ro') #ro #r^ #rv
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.show()

# %%
x = np.array([1, 2, 3, 4, 5, 6])
y1 = np.power(x, 2)
y2 = np.power(x, 3)

plt.figure(figsize=(10,5))

plt.plot(x, y1, "b-" , label='y1 = x^2') 
plt.plot(x, y2, "r-" , label='$y2 = x^3$')   

plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.legend()
plt.show()

# %%
x = np.linspace(0, 10, 2000)  

plt.figure(figsize=(10, 6))

plt.plot(x, np.sin(x), label='$sin(X)$')
plt.plot(x, np.cos(x), label='$cos(X)$')

plt.xlabel(r'$X$' , fontsize = 30)
plt.ylabel(r'$Y$' , fontsize = 18)

plt.title("$Sin(x) $  $ & $  $ Cos(x)$", fontsize=20)

plt.legend(loc='lower right')

plt.show()

# %%
x = np.array([1, 2, 3, 4, 5, 6])
y1 = np.power(x,2)
y2 = np.power(x,3)

plt.figure(figsize=(10, 5))
plt.plot(x, y1, "b-" , label = '$y1 = x^2$') 
plt.plot(x, y2, color='red', linewidth=5.0, linestyle='--', label = '$y2 = x^3$')   

plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")

plt.legend(loc='upper center', fontsize='large')
plt.show()

# %%
x = np.linspace(0, 10, 2000)  
plt.figure(figsize=(16, 9))

plt.plot(x,np.sin(x) , label = '$Sin(X) $  $ Dashed $' , linestyle='dashed')
plt.plot(x + 1,np.sin(x) , label = '$Sin(X) $  $ Dashdot  $' , linestyle='dashdot')
plt.plot(x,np.cos(x) , label = '$cos(X) $ $ Solid $' , linestyle='solid')
plt.plot(x + 1,np.cos(x) , label = '$cos(X)$ $ Dotted $' , linestyle='dotted')

plt.xlabel(r'$X$' , fontsize = 18)
plt.ylabel(r'$Y$' , fontsize = 18)

plt.title("$Sin(x) $  $ & $  $ Cos(x)$" ,fontsize = 14)
plt.legend(loc = 'upper right' , fontsize = 14 , bbox_to_anchor=(0, 1.0)) 
plt.show()

# %%
from sklearn.model_selection import train_test_split
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt

np.random.seed(42)

date_range = pd.date_range(start='2020-01-01', periods=200, freq='D')

data = pd.DataFrame({
    'date': date_range,
    'feature1': np.random.randn(200),
    'feature2': np.random.randn(200),
    'feature3': np.random.randn(200),
    'sales': np.random.randn(200).cumsum() 
})
# Set the date as the index
data.set_index('date', inplace=True)

# %%
train_data, test_data = train_test_split(data, test_size=0.2, shuffle=False)

sarima_model = SARIMAX(train_data['sales'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
sarima_result = sarima_model.fit()

sarima_pred = sarima_result.get_forecast(steps=len(test_data))
sarima_pred_mean = sarima_pred.predicted_mean
# Out:
# c:\Users\Roman\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\Roman\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
plt.figure(figsize=(14, 7))
plt.plot(train_data.index, train_data['sales'], label='y_train')
plt.plot(test_data.index, test_data['sales'], label='y_test')
plt.plot(test_data.index, sarima_pred_mean, label='y_pred', linestyle='--')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales Forecasting with SARIMA')
plt.show()

# %%
plt.figure(figsize=(12, 6))
x = np.linspace(0, 10, 100) 
y1 = np.sin(x) 
y2 = np.cos(x) 

plt.subplot(2, 1, 1) #nrows, ncols, idx
plt.plot(x,y1, "b-")

plt.subplot(2, 1, 2)
plt.plot(x, y2, "r-")
plt.tight_layout()
plt.show()

# %%
x = np.arange(-50,50)
y1 = np.power(x,2)
y2 = np.power(x,3)
y3 = np.sin(x)
y4 = np.cos(x)
y5 = np.tan(x)
y6 = np.tanh(x)
y7 = np.sinh(x)
y8 = np.cosh(x)
y9 = np.exp(x)

fig1, ax1 = plt.subplots(nrows=3, ncols=3 , figsize = (20,20)) 
ax1[0,0].plot(x, y1, "tab:blue") 
ax1[0,0].set_title("Square Function") 
ax1[0,0].set_xlabel(r'$X$' , fontsize = 18) 
ax1[0,0].set_ylabel(r'$Y$' , fontsize = 18) 


ax1[0,1].plot(x, y2, "tab:orange")
ax1[0,1].set_title("Cubic Function")
ax1[0,1].set_xlabel(r'$X$' , fontsize = 18)
ax1[0,1].set_ylabel(r'$Y$' , fontsize = 18)

ax1[0,2].plot(x, y3, "tab:green")
ax1[0,2].set_title("Sine Function")
ax1[0,2].set_xlabel(r'$X$' , fontsize = 18)
ax1[0,2].set_ylabel(r'$Y$' , fontsize = 18)


ax1[1,0].plot(x, y4, "b-")
ax1[1,0].set_title("Cosine Function")
ax1[1,0].set_xlabel(r'$X$' , fontsize = 18)
ax1[1,0].set_ylabel(r'$Y$' , fontsize = 18)


ax1[1,1].plot(x, y5, "r-")
ax1[1,1].set_title("Tangent Function")
ax1[1,1].set_xlabel(r'$X$' , fontsize = 18)
ax1[1,1].set_ylabel(r'$Y$' , fontsize = 18)

ax1[1,2].plot(x, y6, "g-")
ax1[1,2].set_title("Hyperbolic Tangent")
ax1[1,2].set_xlabel(r'$X$' , fontsize = 18)
ax1[1,2].set_ylabel(r'$Y$' , fontsize = 18)

ax1[2,0].plot(x, y7, "m-")
ax1[2,0].set_title("Hyperbolic Sine")
ax1[2,0].set_xlabel(r'$X$' , fontsize = 18)
ax1[2,0].set_ylabel(r'$Y$' , fontsize = 18)

ax1[2,1].plot(x, y8, "y-")
ax1[2,1].set_title("Hyperbolic Cosine")
ax1[2,1].set_xlabel(r'$X$' , fontsize = 18)
ax1[2,1].set_ylabel(r'$Y$' , fontsize = 18)

ax1[2,2].plot(x, y9, "k-")
ax1[2,2].set_title("Exponential Function")
ax1[2,2].set_xlabel(r'$X$' , fontsize = 18)
ax1[2,2].set_ylabel(r'$Y$' , fontsize = 18)

plt.show()

# %% [markdown]
# # Bar Graphs

# %%
id1 = np.arange(1, 10)
score = np.arange(20, 110, 10)

plt.bar(id1, score)

plt.xlabel('Student ID')
plt.ylabel('Score')
plt.show()

# %%
x1 = [1, 3, 5, 7] 
x2 = [2, 4, 6, 8]
y1 = [7, 7, 7, 7]
y2 = [17, 18, 29, 40]

plt.figure(figsize=(8, 6))
ax = plt.axes()
ax.set_facecolor("white")

plt.bar(x1, y1, label = "First", color = '#42B300') 
plt.bar(x2, y2, label = "Second", color = '#94E413') 

plt.xlabel('$X$')
plt.ylabel('$Y$')

plt.title ('$Bar $ $ Chart$')
plt.legend()
plt.show()

# %%
age = [28, 33, 43, 45, 57]
name = ["Roman", "Bohdan", 'Artem', "Egor", "Andrey"]
plt.barh(name, age, color="yellowgreen")
plt.show()

# %% [markdown]
# ### Stacked Vertical Bar

# %%
x1= ["Roman", "Bohdan", 'Artem', "Egor"]
y1= [17, 18, 29, 40]
y2 = [20, 21, 22, 23]

plt.figure(figsize=(5, 7))
plt.bar(x1, y1, label="Виконані завдання", width=0.5, color='#FF6F00')
plt.bar(x1, y2, label="Невиконані завдання", width=0.5, bottom=y1, color='#FFB300')

plt.xlabel('$X$')
plt.ylabel('$Y$')

plt.title ('$Bar $ $ Chart$')
plt.legend()
plt.show()

# %% [markdown]
# ### Stacked Horizontal Bar

# %%
x1 = ["Roman", "Bohdan", 'Artem', "Egor"]
y1 = [17, 18, 29, 40]
y2 = [20, 21, 22, 23]

plt.figure(figsize=(8,5))
plt.barh(x1, y1, label = "Open Tickets", color = '#FF6F00')
plt.barh(x1, y2, label = "Closed Tickets", left = y1 , color = '#FFB300')
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title ('$Bar $ $ Chart$')
plt.legend()
plt.show()

# %% [markdown]
# # Scatter Graphs

# %%
x1 = np.array([250, 150, 350, 252, 450, 550, 455, 358, 158, 355])
y1 = np.array([40, 50, 80, 90, 100, 50,60,88,54,45])


x2 = np.array([200, 100, 300, 220, 400, 500, 450, 380, 180, 350])
y2 = np.array([400, 500, 800, 900, 1000, 500, 600, 808, 504, 405])

#Graph - 1
plt.scatter(x1, y1)
plt.xlabel('$Time $ $ Spent$', fontsize=12)
plt.ylabel('$Score$', fontsize=12)
plt.title ('Scatter Graph')
plt.show()

#Graph - 2
plt.scatter(x2, y2, color='r')
plt.xlabel('$Time $ $ Spent$', fontsize=12)
plt.ylabel('$Score$', fontsize=12)
plt.title ('Scatter Graph')
plt.show()

#Graph - 3
plt.scatter(x1, y1 ,label='Class 1')
plt.scatter(x2, y2 ,label='Class 2',color ='r')
plt.xlabel('$Time $ $ Spent$', fontsize = 12)
plt.ylabel('$Score$', fontsize = 12)
plt.title ('Scatter Graph')
plt.legend()
plt.show()

#Graph - 4
plt.scatter(x1, y1 ,label='Class 1', marker='o', color='m')
plt.scatter(x2, y2 ,label='Class 2', marker='v', color='r')
plt.xlabel('$Time $ $ Spent$' , fontsize = 12)
plt.ylabel('$Score$' , fontsize = 12)
plt.title ('Scatter Graph')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,6))
x = np.random.normal(0,10,1000)
y = np.random.normal(0,10,1000)
plt.scatter(x,y)
plt.show()

# %%
x = np.random.random(10)
y = np.random.random(10)

plt.figure(figsize=(8,6))

plt.scatter(np.random.random(10), np.random.random(10), c='r', s=50, alpha=1, label='One' )
plt.scatter(np.random.random(10), np.random.random(10), c='b', s=100, alpha=1, label='Two')
plt.scatter(np.random.random(10), np.random.random(10), c='g', s=150, alpha=1, label='Three')
plt.scatter(np.random.random(10), np.random.random(10), c='y', s=500, alpha=0.4, label='Four')

plt.legend(bbox_to_anchor=(1.0, 1), fontsize='small')
plt.show()

# %% [markdown]
# # Pie Charts

# %%
plt.figure(figsize=(6,6))
tickets = [48, 30, 20, 15]
labels = ['Low' , 'Medium' , 'High' , 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']
plt.pie(tickets , labels=labels , colors=colors , startangle=45)
plt.show()

# %% [markdown]
# #### Display percentage and actual value in Pie Chart

# %%
tickets = [48 , 30 , 20 , 15]
labels = ['Low' , 'Medium' , 'High' , 'Critical']
colors = ['#7CB342','#C0CA33','#FFB300','#F57C00']

plt.figure(figsize=(8,8))

plt.pie (tickets, labels=labels ,colors=colors, startangle=45, autopct='%.2f%%', explode=[0.1, 0.1, 0, 0.1])
plt.show()

# %% [markdown]
# #### Display multiple pie plots in one figure

# %%
fig = plt.figure(figsize=(20, 6))
tickets = [48, 30, 20, 15]
priority = ['Low', 'Medium', 'High', 'Critical']
status = ['Resolved', 'Cancelled', 'Pending', 'Assigned']
company = ['IBM', 'Microsoft', 'BMC', 'Apple']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']

plt.subplot(1, 3, 1)
plt.pie (tickets , labels=priority , colors=colors , startangle=45)


plt.subplot(1,3,2)
plt.pie (tickets , labels=status , colors=colors , startangle=45)


plt.subplot(1,3,3)
plt.pie (tickets , labels=company , colors=colors , startangle=45)


plt.show()

# %% [markdown]
# # Histogram

# %%
x = np.random.normal(size=2000)

plt.hist(x, bins=2000, color='yellowgreen')
plt.gca().set(title='Histogram', xlabel='distr', ylabel='Frequency')
plt.show()

# %%
plt.figure(figsize=(7,7))
x = np.random.normal(size = 2000)
plt.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram', ylabel='Frequency')
plt.show()

# %% [markdown]
# ### Binning

# %%
# Binning
plt.figure(figsize=(10,8))
x = np.random.normal(size = 2000)
plt.hist(x, bins=30, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram', ylabel='Frequency')
plt.show()

plt.figure(figsize=(10,8))
plt.hist(x, bins=20, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram', ylabel='Frequency')
plt.show()

plt.figure(figsize=(10,8))
plt.hist(x, bins=10, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram', ylabel='Frequency')
plt.show()

# %% [markdown]
# #### Plotting Multiple Histograms

# %%
x = np.random.normal(-4,1,size = 800)
y = np.random.normal(0,1.5,size = 800)
z = np.random.normal(3.5,1,size = 800)

plt.figure(figsize=(7,7))

plt.hist(x, bins=30, color='yellowgreen' , alpha=0.6)
plt.hist(y, bins=30, color='#FF8F00' , alpha=0.6)
plt.hist(z, bins=30, color='blue' , alpha=0.6)

plt.gca().set(title='Histogram', ylabel='Frequency')
plt.show()

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %%
data = sns.load_dataset('iris')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
data[data['species'] == 'setosa'].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000

# %%
plt.figure(figsize=(3, 4))
sns.boxplot(x='species', y='sepal_length', data=data[data['species'] == 'setosa'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(x='species', y='sepal_width', data=data)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.barplot(x="species", y="sepal_width", data=data)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
corr = data.drop(['species'], axis=1).corr()

sns.heatmap(corr, cmap='Blues', annot=True)
# Out:
# <Axes: >

# %%
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000
